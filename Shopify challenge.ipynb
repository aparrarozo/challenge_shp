# %%
import pandas as pd
import numpy as np
import seaborn as sns
#import matplotlib.pyplot as plt
#%matplotlib inline

# %%
df= pd.read_csv("Copy of 2019 Winter Data Science Intern Challenge Data Set - Sheet1.csv")

# %%
df
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                created_at
# 0     2017-03-13 12:36:56
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5000 non-null   int64
#  1   shop_id         5000 non-null   int64
#  2   user_id         5000 non-null   int64
#  3   order_amount    5000 non-null   int64
#  4   total_items     5000 non-null   int64
#  5   payment_method  5000 non-null   object
#  6   created_at      5000 non-null   object
# dtypes: int64(5), object(2)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.drop_duplicates()
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                created_at
# 0     2017-03-13 12:36:56
# ...

# %%
df.shape
# Out:
# (5000, 7)

# %%
shops= df.shop_id.unique()
len(shops)
# Out:
# 100

# %%
#initial 'naively' calculated aov
naif_aov= df.order_amount.mean()
naif_aov
# Out:
# 3145.128

# %% [raw]
# The 'naively' calculated AOV is the mean of the ordered amounts without taking into account the variability between stores or possible irregularities. A better measure would be the median of the orders, as it is not affected by outliers.

# %%
orders_median= np.median(df.order_amount)
orders_median
# Out:
# 284.0

# %% [raw]
# The median order value is $284.This gives us a much clearer idea of the amount being purchased and is within the range of prices for a pair of sneakers sold in our stores.

# %% [raw]
# Further analysis explains why the average amount has such a high value.

# %%
# visualize order amount 
df.hist(column='order_amount')
# Out:
# array([[<AxesSubplot:title={'center':'order_amount'}>]], dtype=object)

# %%
df.hist(column='total_items')
# Out:
# array([[<AxesSubplot:title={'center':'total_items'}>]], dtype=object)

# %%
sns.barplot(data=df, x="total_items", y="order_amount")
# Out:
# <AxesSubplot:xlabel='total_items', ylabel='order_amount'>

# %%
# check specific quantities sold
df.total_items.value_counts()
# Out:
# 2       1832
# 1       1830
# 3        941
# 4        293
# 5         77
# 2000      17
# 6          9
# 8          1
# Name: total_items, dtype: int64

# %%
# inspect rows with outliers
df[df['total_items'] == 2000]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# ...

# %% [raw]
# All transactions for $2000 are virtually the same:
# They come from the same user, at the same store, payed by credit card and happen at the same time of day. I would consider this as suspicious activity and check both user and shop to inspect their other transactions.

# %%
#Check user
user_607 = df[df['user_id'] == 607]
user_607
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# ...

# %%
df[df['shop_id'] == 42]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 40          41       42      793           352            1    credit_card
# 60          61       42      607        704000         2000    credit_card
# 308        309       42      770           352            1    credit_card
# 409        410       42      904           704            2    credit_card
# 520        521       42      607        704000         2000    credit_card
# 834        835       42      792           352            1           cash
# 835        836       42      819           704            2           cash
# 938        939       42      808          1056            3    credit_card
# 979        980       42      744           352            1          debit
# 1104      1105       42      607        704000         2000    credit_card
# ...

# %% [raw]
# In addition to the repeatedly exhorbitant amount, user 607 has made no other transactions in any other stores, so it looks like a fraudulent transaction.
# The price per pair in the shop is abnormally high. I would suggest to review the data from this store, confirm the price and make sure it is not a scam.
# Remove these transactions to proceed with the analysis.

# %%
#remove shop id 42
no_fraud_df = df[df.shop_id != 42]

# %%
no_fraud_df.total_items.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
#looking at price per pair of shoes

# %%
individual_pair= no_fraud_df.query('total_items== 1')
individual_pair
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# 5            6       58      882           138            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4986      4987      100      731           111            1           cash
# 4987      4988       11      826           184            1    credit_card
# 4990      4991       24      860           140            1           cash
# 4991      4992       61      707           158            1           cash
# 4994      4995       12      954           201            1           cash
#
#                created_at
# 1     2017-03-03 17:38:52
# ...

# %%
individual_pair['order_amount'].unique()
# Out:
# array([   90,   144,   156,   138,   149,   146,   111,   176,   164,
#          177,   145,   112,   178,   148,   195,   181,   187,   160,
#          184,   122,   130,   116,   142,   127,   132,   118,   193,
#          201,   129,   136,   165,   153,   173, 25725,   147,   117,
#          163,   133,   114,   171,   128,   190,   131,   161,   158,
#          166,   134,   154,   172,   169,    94,   168,   196,   140,
#          101,   162,   155])

# %%
sns.barplot(data=no_fraud_df, x="total_items", y="order_amount")
# Out:
# <AxesSubplot:xlabel='total_items', ylabel='order_amount'>

# %%
no_fraud_df[no_fraud_df['total_items'] == 6]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 691        692       78      878        154350            6          debit
# 1563      1564       91      934           960            6          debit
# 2127      2128       83      745           774            6           cash
# 2307      2308       61      723           948            6    credit_card
# 3252      3253       67      706           786            6    credit_card
# 3538      3539       43      830          1086            6          debit
# 3865      3866       68      815           816            6          debit
# 4711      4712       86      883           780            6           cash
# 4847      4848       13      993           960            6           cash
#
#                created_at
# 691   2017-03-27 22:51:43
# 1563   2017-03-23 8:25:49
# 2127   2017-03-27 6:59:46
# 2307  2017-03-26 11:29:37
# 3252  2017-03-29 16:05:41
# 3538  2017-03-17 19:56:29
# 3865   2017-03-11 9:31:50
# ...

# %%
# inspect store with unusually high price per pair
no_fraud_df[no_fraud_df['shop_id'] == 78]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 160        161       78      990         25725            1    credit_card
# 490        491       78      936         51450            2          debit
# 493        494       78      983         51450            2           cash
# 511        512       78      967         51450            2           cash
# 617        618       78      760         51450            2           cash
# 691        692       78      878        154350            6          debit
# 1056      1057       78      800         25725            1          debit
# 1193      1194       78      944         25725            1          debit
# 1204      1205       78      970         25725            1    credit_card
# 1259      1260       78      775         77175            3    credit_card
# 1384      1385       78      867         25725            1           cash
# ...

# %% [raw]
# Given the extremely hight price in comparaison with the rest of the items in other stores(25725$/pair), it'd be important to verify the data from shop_id78. For the analysis, I'll proceed without the store 78.

# %%
#remove shop 78
no_fraud_df = no_fraud_df[no_fraud_df.shop_id != 78]

# %%
no_fraud_df.hist(column='total_items')
# Out:
# array([[<AxesSubplot:title={'center':'total_items'}>]], dtype=object)

# %%
sns.scatterplot(data=no_fraud_df, x='total_items', y="order_amount", alpha=0.2)
# Out:
# <AxesSubplot:xlabel='total_items', ylabel='order_amount'>

# %%
individual_pair= no_fraud_df.query('total_items== 1')
#distribution of the price per pair
individual_pair.hist(column='order_amount')
# Out:
# array([[<AxesSubplot:title={'center':'order_amount'}>]], dtype=object)

# %%
sns.barplot(data=no_fraud_df, x="total_items", y="order_amount")
# Out:
# <AxesSubplot:xlabel='total_items', ylabel='order_amount'>

# %% [raw]
# Through the initial analysis, two shops id78 and id42 were found to have some irregularities that affected strongly the AOV. If we leave them out of the dataset, we can see a more consequent between prices and the number of items purchased. However we can't completely exclude the possibility of having stores that sell particularly expensive items or a shop having a problem with the system.
#
# The median allows us to have a better picture of the overall amounts beeing purchased and we can further investigate and verify the particular cases that could be distorting the rest of the data.
